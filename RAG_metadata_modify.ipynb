# %%
# !pip install --upgrade boto3==1.39.8
import io
import os
import random
import nltk
import boto3
import requests
import json
from io import BytesIO
import tempfile
import pandas as pd
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

S3_BUCKET = "ml-legal-restricted"
EXCEL_PATH = "full_contracts_with_files.xlsx"
VECTOR_BUCKET_NAME = "legal-docs-vector-store"
SOURCE_INDEX = 'token-chunking-poc'
TARGET_INDEX = 'token-chunking-metadata-enriched'

nltk.download('punkt')
nltk.download('punkt_tab')
s3 = boto3.client('s3')
s3v = boto3.client("s3vectors", region_name="us-east-1")
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
INDEX_NAME = 'token-chunking-metadata-enriched'

paginator = s3v.get_paginator('list_vectors')

total_vectors_count = 0

page_iterator = paginator.paginate(
    vectorBucketName=VECTOR_BUCKET_NAME,
    indexName=INDEX_NAME,
    returnData=True,
    returnMetadata=True,
    PaginationConfig={
        'PageSize': 1000  
    }
)

for page in page_iterator:
    vectors = page.get('vectors', [])
    total_vectors_count += len(vectors)

print(f"Total chunks vector & stored: {total_vectors_count}")
# Out:
# Total chunks vector & stored: 17598

# %%
csv_path = 'gathered_contract_files.csv'
csv_df = pd.read_csv(csv_path)

excel_df = pd.read_excel(EXCEL_PATH, sheet_name="Active Legal Contracts", dtype={"Parent Contract": str})

csv_df.columns = [col.strip().lower().replace(' ', '_') for col in csv_df.columns]
excel_df.columns = [col.strip().lower().replace(' ', '_') for col in excel_df.columns]

merged_df = pd.merge(csv_df, excel_df, on='contract_number', how='left')

def get_additional_metadata(s3_full_path, merged_df):

    row = merged_df[merged_df['s3_full_path'] == s3_full_path]
    if row.empty:
        print('its empty')
        return {}

    additional_metadata_keys = [
        'parent_contract', 'status_reason', 'solution_line', 'contract_title', 'contract_requester',
        'reviewing_attorney', 'created_on', 'document_effective_date'
    ]

    additional_metadata = row[additional_metadata_keys].iloc[0].dropna().to_dict()
    for k, v in additional_metadata.items():
        if pd.isna(v):
            additional_metadata[k] = None
        elif hasattr(v, 'strftime'):
            additional_metadata[k] = v.strftime('%Y-%m-%d')
        else:
            additional_metadata[k] = str(v)

    additional_metadata = {k: v for k, v in additional_metadata.items() if v is not None}
    return additional_metadata

enriched_metadata_list = []

for idx, row in csv_df.iterrows():
    s3_path = row['s3_full_path']
    additional_meta = get_additional_metadata(s3_path, merged_df)
    enriched_metadata_list.append(additional_meta)

enriched_meta_df = pd.DataFrame(enriched_metadata_list)

final_df = pd.concat([csv_df.reset_index(drop=True), enriched_meta_df], axis=1)

final_df.to_csv('gathered_contract_files_enriched.csv', index=False)

print("Enriched CSV saved to: gathered_contract_files_enriched.csv")
# Out:
# Enriched CSV saved to: gathered_contract_files_enriched.csv

# %%
def get_additional_metadata(s3_full_path, merged_df):
    try:
        row = merged_df[merged_df['s3_full_path'] == s3_full_path]
        if row.empty:
            print(f"No metadata found for s3_full_path: {s3_full_path}")
            return {}

        additional_metadata_keys = [
            'parent_contract', 'status_reason', 'solution_line', 'contract_title', 'contract_requester',
            'reviewing_attorney', 'created_on', 'document_effective_date'
        ]

        additional_metadata = row[additional_metadata_keys].iloc[0].to_dict()

        for k, v in additional_metadata.items():
            if pd.isna(v):
                additional_metadata[k] = None
            elif hasattr(v, 'strftime'):
                additional_metadata[k] = v.strftime('%Y-%m-%d')
            else:
                additional_metadata[k] = str(v)

        return {k: v for k, v in additional_metadata.items() if v is not None}

    except Exception as e:
        print(f"Error in get_additional_metadata for {s3_full_path}: {e}")
        return {}


def list_vectors_batch(index_name, bucket_name, max_results=500, next_token=None):
    try:
        params = {
            'indexName': index_name,
            'vectorBucketName': bucket_name,
            'maxResults': max_results,
            'returnData': True,
            'returnMetadata': True
        }
        if next_token:
            params['nextToken'] = next_token

        response = s3v.list_vectors(**params)
        return response.get('vectors', []), response.get('nextToken')

    except Exception as e:
        print(f"Error in list_vectors_batch: {e}")
        return [], None


def insert_vectors_batch(index_name, bucket_name, vectors):
    try:
        entries = [{
            'key': v['key'],
            'data': v['data'],
            'metadata': v['metadata']
        } for v in vectors]

        response = s3v.put_vectors(
            indexName=index_name,
            vectorBucketName=bucket_name,
            vectors=entries
        )
        return response

    except Exception as e:
        print(f"Error in insert_vectors_batch: {e}")
        return None


def migrate_vectors_with_metadata_update(source_index, target_index, bucket_name, df, batch_size=500):
    next_token = None

    while True:
        vectors, next_token = list_vectors_batch(source_index, bucket_name, batch_size, next_token)
        if not vectors:
            print("No vectors found in this batch. Ending migration.")
            break

        for vec in vectors:
            try:
                if 'metadata' not in vec or vec['metadata'] is None:
                    vec['metadata'] = {}

                s3_path = vec['metadata'].get('s3_path', '').strip()
                
                if s3_path:
                    dynamic_metadata = get_additional_metadata(s3_path, df)
                    vec['metadata'].update(dynamic_metadata)

                    for key in ['file_name', 'contract_number', 'opensearch', 's3_vectors']:
                        if key in vec['metadata']:
                            del vec['metadata'][key]
                    
                    created_on = dynamic_metadata.get('created_on')
                    document_effective_date = dynamic_metadata.get('document_effective_date')
                    contract_requester = dynamic_metadata.get('contract_requester')
                    reviewing_attorney = dynamic_metadata.get('reviewing_attorney')
                    client_account = dynamic_metadata.get('client_account')
                    parent_contract = dynamic_metadata.get('parent_contract')

                    vec['metadata']['dates'] = [date for date in [created_on, document_effective_date] if date is not None]
                    vec['metadata']['attorneys'] = [attorney for attorney in [contract_requester, reviewing_attorney] if attorney is not None]
                    vec['metadata']['client_account'] = [account for account in [client_account, parent_contract] if account is not None]

                    for old_key in ['created_on', 'document_effective_date', 'contract_requester', 'reviewing_attorney','client_account', 'parent_contract']:
                        if old_key in vec['metadata']:
                            del vec['metadata'][old_key]

                else:
                    print(f"No s3_path found in vector metadata: {vec.get('metadata')}")

            except Exception as e:
                print(f"Error processing vector {vec.get('vectorKey')}: {e}")

        response = insert_vectors_batch(target_index, bucket_name, vectors)

        if response is not None:
            print(f"Inserted batch of {len(vectors)} vectors to {target_index}")
        else:
            print("Failed to insert batch to target index.")

        if not next_token:
            print("Completed migrating all vectors.")
            break


df = pd.read_csv('gathered_contract_files_enriched.csv', dtype={"parent_contract": str})
migrate_vectors_with_metadata_update(SOURCE_INDEX, TARGET_INDEX, VECTOR_BUCKET_NAME, df)
# Out:
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 500 vectors to token-chunking-metadata-enriched
# Inserted batch of 98 vectors to token-chunking-metadata-enriched
# Completed migrating all vectors.

# %%
import numpy as np
EMBEDINNGS_URL = "https://zgggzg2iqg.execute-api.us-east-1.amazonaws.com/dev/get_embeddings"
API_KEY = "2jIpWCyNRg3Y8lkbmWG0tkyXwYlJn5QaZ1F3yKf7"

def get_text_embedding(texts, model='e5_mistral_embed_384'):
    if isinstance(texts, str):
        texts = [texts]
        
    if not isinstance(texts, list) or not texts:
        raise ValueError("Input 'texts' must be a non-empty list of strings.")

    embeddings = []

    for text in texts:
        if not isinstance(text, str):
            raise ValueError("Each item in 'texts' must be a string.")

        payload = {
            "model_name": model,
            "texts": [text]
        }

        headers = {
        "x-api-key": API_KEY
        }

        try:
            response = requests.post(EMBEDINNGS_URL, json=payload, headers=headers)
            response.raise_for_status()

            raw_body = response.json().get('body')

            parsed_body = json.loads(raw_body)

            embedding = parsed_body.get('embeddings')
            if not embedding or not isinstance(embedding, list) or len(embedding) != 1:
                raise KeyError(f"No valid embedding found in response for text: '{text}'")

            # embeddings.append(embedding[0])
            embedding_float32 = np.array(embedding[0], dtype=np.float32).tolist()
            embeddings.append(embedding_float32)
        except Exception as e:
            print(f"[ERROR] Failed to get embedding!") #for '{text}': {e}")
            embeddings.append(None)

    return embeddings[0] if len(embeddings) == 1 else embeddings


def query_s3_vector_store(query_text, client_account_filter, INDEX_NAME, top_k = 5):
    print(f"\n--- Processing Query: '{query_text}' ---")

    query_embedding = get_text_embedding(query_text)
    filter_expression = None
    if client_account_filter is not None:
        filter_expression = {
            "client_account": {
                "$eq": client_account_filter
            }
        }

    try:
        response = s3v.query_vectors(
            vectorBucketName=VECTOR_BUCKET_NAME,
            indexName=INDEX_NAME,
            topK=top_k,
            queryVector={
                'float32': query_embedding
            },
            returnMetadata=True,
            returnDistance=True,
            filter=filter_expression
        )
        return response
    except Exception as e:
        print(f"Error querying S3 Vector Store: {e}")
        return None

user_questions = [
    "What obligations does Cotiviti have under Schedule C for Prepay FWAV Services?", #66179
    "Under Schedule C, what services is Cotiviti required to provide?", #66179
    "In the Prepay FWAV Services section, what are Cotiviti's main deliverables?", #66179
    "What restrictions are placed on disclosing confidential information?", #67566
    "What is Amendment #4 to the Verisk Health License Agreement about?", #53985
    "What is the purpose of Amendment #4 as stated in the document?", #53985
]

INDEX_NAME = "token-chunking-metadata-enriched"
client = None #'UST Global'

for question in user_questions:
    query_results = query_s3_vector_store(question, client, INDEX_NAME, top_k=5)

    if query_results and 'vectors' in query_results:
        print(f"Retrieved {len(query_results['vectors'])}")
        for i, chunk_data in enumerate(query_results['vectors']):
            print(f"    Metadata {i+1}: {chunk_data['metadata']}")
            # print(f"    Distance: {chunk_data.get('distance', 'N/A')}")
    else:
        print(f"No results or an error occurred for query: '{question}'")
# Out:
# --- Processing Query: 'What obligations does Cotiviti have under Schedule C for Prepay FWAV Services?' ---
# Retrieved 5
#     Metadata 1: {'status_reason': 'Fully-Executed/Complete', 'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.', 's3_path': 's3://ml-legal-restricted/contract-docs/58295/Dynamics_58295__Please_review_and_sign_your_d_signed.pdf', 'contract_title': 'SOW to MSA (12/2/2019)', 'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam'], 'dates': ['2019-12-10', '2020-01-01'], 'document_type': 'SOW'}
#     Metadata 2: {'dates': ['2019-12-10', '2020-01-01'], 'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam'], 'document_type': 'SOW', 'status_reason': 'Fully-Executed/Complete', 'contract_title': 'SOW to MSA (12/2/2019)', 's3_path': 's3://ml-legal-restricted/contract-docs/58295/ATKOTT Inc - Cotiviti - SOW - MV - 01102020 - Dynamics_58295.pdf', 'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.'}
#     Metadata 3: {'attorneys': ['Nishan Khoshafian', 'Jeffrey Koslowski'], 'solution_line': 'Payment Accuracy', 'contract_title': 'AMD#11 to CV Schedule 15 adding PCCV', 'document_type': 'Amendment', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/60533/Aetna AMD#8 to Schedule 15 4-22-21.docx', 'dates': ['2020-10-21', '2021-09-30'], 'text': 'Cotiviti invoices will be paid in accordance with the Agreement.'}
#     Metadata 4: {'text': 'Client will pay Cotiviti invoicing within 45 days of receipt of invoice. SCHEDULE C\nEXAMPLE REPORTS\n\nSUMMARY OPV\n\nDETAILS PAR RECD NO HX\n\n\nDETAILS NORESPONSE ADL-APL\n\nDETAILS NORESPONSE MR\n\nNO RESPONSE ON MR\nNO RESPONSE MR DETAIL \n\n\nPROVIDER SUMMARY\n\n\nWEEKLY STATUS REPORT', 'solution_line': 'Payment Accuracy', 'contract_title': 'CCV SOW', 's3_path': 's3://ml-legal-restricted/contract-docs/70428/1199 CCV SOW redline 7-21-23.docx', 'attorneys': ['Mike McFadden', 'Jeffrey Koslowski'], 'dates': ['2022-12-02', '2023-10-10'], 'document_type': 'SOW', 'status_reason': 'Fully-Executed/Complete'}
#     Metadata 5: {'solution_line': 'Payment Accuracy', 'attorneys': ['Mike McFadden', 'Jeffrey Koslowski'], 'text': 'Cotiviti will invoice according to the Agreement. Invoice delivery date will occur on or about the fifteenth (15th) of every month with the exceptions of weekends and U.S. Holidays. Client will pay Cotiviti invoicing within 45 business days of receipt of invoice.', 'document_type': 'SOW', 'dates': ['2022-12-02', '2023-10-10'], 's3_path': 's3://ml-legal-restricted/contract-docs/70428/1199 CCV SOW redline 4-5-23.docx', 'status_reason': 'Fully-Executed/Complete', 'contract_title': 'CCV SOW'}
#
# --- Processing Query: 'Under Schedule C, what services is Cotiviti required to provide?' ---
# Retrieved 5
#     Metadata 1: {'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam'], 'document_type': 'SOW', 'status_reason': 'Fully-Executed/Complete', 'contract_title': 'SOW to MSA (12/2/2019)', 'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.', 'dates': ['2019-12-10', '2020-01-01'], 's3_path': 's3://ml-legal-restricted/contract-docs/58295/Dynamics_58295__Please_review_and_sign_your_d_signed.pdf'}
#     Metadata 2: {'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.', 'dates': ['2019-12-10', '2020-01-01'], 'contract_title': 'SOW to MSA (12/2/2019)', 'document_type': 'SOW', 'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam'], 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/58295/ATKOTT Inc - Cotiviti - SOW - MV - 01102020 - Dynamics_58295.pdf'}
#     Metadata 3: {'s3_path': 's3://ml-legal-restricted/contract-docs/60533/Aetna AMD#8 to Schedule 15 4-22-21.docx', 'dates': ['2020-10-21', '2021-09-30'], 'solution_line': 'Payment Accuracy', 'attorneys': ['Nishan Khoshafian', 'Jeffrey Koslowski'], 'text': 'Cotiviti invoices will be paid in accordance with the Agreement.', 'contract_title': 'AMD#11 to CV Schedule 15 adding PCCV', 'document_type': 'Amendment', 'status_reason': 'Fully-Executed/Complete'}
#     Metadata 4: {'document_type': 'SOW', 'contract_title': 'CCV SOW', 'dates': ['2022-12-02', '2023-10-10'], 'attorneys': ['Mike McFadden', 'Jeffrey Koslowski'], 'solution_line': 'Payment Accuracy', 'text': 'Client will pay Cotiviti invoicing within 45 days of receipt of invoice. SCHEDULE C\nEXAMPLE REPORTS\n\nSUMMARY OPV\n\nDETAILS PAR RECD NO HX\n\n\nDETAILS NORESPONSE ADL-APL\n\nDETAILS NORESPONSE MR\n\nNO RESPONSE ON MR\nNO RESPONSE MR DETAIL \n\n\nPROVIDER SUMMARY\n\n\nWEEKLY STATUS REPORT', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/70428/1199 CCV SOW redline 7-21-23.docx'}
#     Metadata 5: {'solution_line': 'Record Import/Clean Up', 'document_type': 'Statement of Destruction', 'attorneys': ['Tony Potts', 'ihtech Simko'], 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/61691/RE DD 2021- 021 - Errant Data Received into Aetna Encounter Data System from Third Party CSSC Operations.msg', 'contract_title': 'Aetna - CSSC - Data Destruction Letter - 20210408', 'text': 'Please contact InformationGovernance@cotiviti.com <mailto:InformationGovernance@cotiviti.com>  with any questions.', 'dates': ['2021-04-08', '2021-03-02']}
#
# --- Processing Query: 'In the Prepay FWAV Services section, what are Cotiviti's main deliverables?' ---
# Retrieved 5
#     Metadata 1: {'s3_path': 's3://ml-legal-restricted/contract-docs/58295/Dynamics_58295__Please_review_and_sign_your_d_signed.pdf', 'contract_title': 'SOW to MSA (12/2/2019)', 'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.', 'status_reason': 'Fully-Executed/Complete', 'dates': ['2019-12-10', '2020-01-01'], 'document_type': 'SOW', 'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam']}
#     Metadata 2: {'dates': ['2019-12-10', '2020-01-01'], 'status_reason': 'Fully-Executed/Complete', 'contract_title': 'SOW to MSA (12/2/2019)', 'text': '1  \n  \n   \n \n \n \nSTATEMENT OF WORK  \n \nPrepared for  \n \nCotiviti, Inc.', 'attorneys': ['Natalie Wise', 'Mahalakshmi Vyakaranam'], 'document_type': 'SOW', 's3_path': 's3://ml-legal-restricted/contract-docs/58295/ATKOTT Inc - Cotiviti - SOW - MV - 01102020 - Dynamics_58295.pdf'}
#     Metadata 3: {'status_reason': 'Fully-Executed/Complete', 'contract_title': 'AMD#11 to CV Schedule 15 adding PCCV', 's3_path': 's3://ml-legal-restricted/contract-docs/60533/Aetna AMD#8 to Schedule 15 4-22-21.docx', 'document_type': 'Amendment', 'attorneys': ['Nishan Khoshafian', 'Jeffrey Koslowski'], 'text': 'Cotiviti invoices will be paid in accordance with the Agreement.', 'dates': ['2020-10-21', '2021-09-30'], 'solution_line': 'Payment Accuracy'}
#     Metadata 4: {'document_type': 'SOW', 'text': 'Cotiviti will invoice according to the Agreement. Invoice delivery date will occur on or about the fifteenth (15th) of every month with the exceptions of weekends and U.S. Holidays. Client will pay Cotiviti invoicing within 45 business days of receipt of invoice.', 'attorneys': ['Mike McFadden', 'Jeffrey Koslowski'], 'dates': ['2022-12-02', '2023-10-10'], 's3_path': 's3://ml-legal-restricted/contract-docs/70428/1199 CCV SOW redline 4-5-23.docx', 'contract_title': 'CCV SOW', 'solution_line': 'Payment Accuracy', 'status_reason': 'Fully-Executed/Complete'}
#     Metadata 5: {'contract_title': 'CCV SOW', 's3_path': 's3://ml-legal-restricted/contract-docs/70428/1199 - Standard CCV SOW 12-7-22.docx', 'attorneys': ['Mike McFadden', 'Jeffrey Koslowski'], 'document_type': 'SOW', 'dates': ['2022-12-02', '2023-10-10'], 'text': 'Cotiviti will invoice according to the Agreement. Invoice delivery date will occur on or about the fifteenth (15th) of every month with the exceptions of weekends and U.S. Holidays.', 'solution_line': 'Payment Accuracy', 'status_reason': 'Fully-Executed/Complete'}
#
# --- Processing Query: 'What restrictions are placed on disclosing confidential information?' ---
# Retrieved 5
#     Metadata 1: {'attorneys': ['Mark Morrall', 'Swapnil Kumari'], 'contract_title': 'Advise Insurance - NDA', 'dates': ['2022-02-17', '2022-02-16'], 'text': '“Confidential Information” \nincludes, without limitation,  intellectual property and trade \nsecrets , ideas, concepts, designs, specifications, drawings, \ntracings, models, samples, data, media, know -how, \ndesigns, drawings, specification s, software programs, \nsoftware documentation, software source codes, technical \ninformation,  software, computer programs, computer files , \nconcepts, inventions, reports, methods, processes, \ntechniques, operations, devices and the like , marketing \nplans and st rategies, business strategies, customer names, \nmailing lists, prices, rates, costs, information received from \nothers that the disclosing party is obligated to treat as \nconfidential, and other technical, financial or business \ninformation , , whether or not t he foregoing information is \npatented, tested, reduced to practice, or subject to \ncopyright . Confidential Information may be furnished in \nany tangible or intangible form, including written or \nprinted documents, visual demonstrations or inspections, \ncompute r disks, or tapes, other electronic media and oral \ncommunications.', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/67562/Advise Insurance - Cotiviti - NDA - SK - 03042022 - Dynamics_67562.pdf', 'document_type': 'NDA', 'solution_line': 'Population Health Management'}
#     Metadata 2: {'contract_title': 'Advise Insurance - NDA', 'text': '“Confidential Information” \nincludes, without limitation,  intellectual property and trade \nsecrets , ideas, concepts, designs, specifications, drawings, \ntracings, models, samples, data, media, know -how, \ndesigns, drawings, specification s, software programs, \nsoftware documentation, software source codes, technical \ninformation,  software, computer programs, computer files , \nconcepts, inventions, reports, methods, processes, \ntechniques, operations, devices and the like , marketing \nplans and st rategies, business strategies, customer names, \nmailing lists, prices, rates, costs, information received from \nothers that the disclosing party is obligated to treat as \nconfidential, and other technical, financial or business \ninformation , , whether or not t he foregoing information is \npatented, tested, reduced to practice, or subject to \ncopyright . Confidential Information may be furnished in \nany tangible or intangible form, including written or \nprinted documents, visual demonstrations or inspections, \ncompute r disks, or tapes, other electronic media and oral \ncommunications.', 'solution_line': 'Population Health Management', 'attorneys': ['Mark Morrall', 'Swapnil Kumari'], 'dates': ['2022-02-17', '2022-02-16'], 'document_type': 'NDA', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/67562/Dynamics_-_67562_signed.pdf'}
#     Metadata 3: {'attorneys': ['Matthew Mercado', 'Manisha Sen'], 'contract_title': 'Edifecs - NDA - Accordion Partners LLC', 'status_reason': 'Fully-Executed/Complete', 'document_type': 'NDA', 'dates': ['2025-06-06'], 's3_path': 's3://ml-legal-restricted/contract-docs/80211/Accordion Partners_NDA_11192020_fully executed.pdf', 'text': "Confidential \nInformati on does not include information that (i) is or becomes \npublicly or generally available th rough no wrongful act; ( ii) is \nconfirmed by Discloser or a third- party owner (e.g. customer or \naffiliate of discloser)  to no longer be confidential ; provided, \nhowever,  that if a Disclosing Party has identifie d such \ninformation as Confidential Information , the Receiving Party  \nshall not disclose it or use it for any unauthorized purpose in \nviolation of Section 3 until thirty (30) days after written notice of \nintent to disclose or use is given to the Disclosing Party along \nwith the asserted grounds for disclosure  or use . Additionally, \nnotwithstanding anything to the contrary herein, if the Receiving Party becomes legally obligated to disclose to a governmental entity with jurisdiction over it, it may do so, provided that, the Receiving Party will g ive the Disclosing Party prompt written \nnotice to allow the Disclosing Party to seek a protective order or other appropriate remedy. Such notice must include, without limitation, identification of the information to be so disclosed and a copy of the order. Following such notification, the Receiving \nParty shall cooperate with the Disclosing Party, at the Disclosing Party's reasonable expense, in seeking and obtaining protection for the Disclosing Par ty's Confidential Information. The \nReceiving Party will di sclose only such information as is legally \nrequired. 3. Use of Confidential Information. Each \nparty agrees not to use any Confidential Information disclosed to it by the other party except as reasonably necessary to carry \nout discussions concerning, or the undertaking of, the \nRelationship."}
#     Metadata 4: {'dates': ['2025-06-06', '2020-02-21'], 'contract_title': 'Edifecs - NDA - ACOF Investment', 's3_path': 's3://ml-legal-restricted/contract-docs/80217/ACOF_NDA_02212020_fully executed.pdf', 'document_type': 'NDA', 'attorneys': ['Matthew Mercado', 'Manisha Sen'], 'text': 'Confidential Information does not \ninclude information that (i) is or becomes generally available to \nthe public through no wrongful act by the Receiving Party or such \nPersonnel (as defined below) in breach of this Agreement; (ii) was \nor is confirmed by Disclosing Party or its Personnel to no longer \nbe Confidential Information; provi ded, however, that if the\nDisclosing Party has identified such information to the Receiving \nParty as Confidential Information, the Receiving Party shall not disclose it (except as otherwise permitted herein) or use it for \nany unauthorized purpose in violation of Section 3 until after \nwritten notice (email being sufficient) of intent to disclose or use \nis given to the Disclosing Party; (iii) was or is in the Receiving Party’s or any of its Personnel’s’ possession prior to disclosure to the Receiving Party or such Personnel; (iv) is or becomes \navailable to the Receiving Party or any of its Personnel from a \nsource other than the Disclosing Party, provided that, to the knowledge of the Receiving Party or such Personnel, as applicable, such source is not restricted by an obligation of \nconfidentiality to the Disclosing Party with respect to such \ninformation or (v) was or is independently developed by the Receiving Party or any of its Personnel without use of, or reference to, Confidential Information.', 'status_reason': 'Fully-Executed/Complete'}
#     Metadata 5: {'dates': ['2025-05-27', '2022-05-11'], 'contract_title': 'Edifecs - 3M_56776-22 Edifecs New BPA_6.0.0 2023-01-26_Fully Executed', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/79736/3M_56776-22 Edifecs New BPA_6.0.0 2023-01-26_Fully Executed.pdf', 'attorneys': ['Marlo Rice', 'Adam Speer'], 'document_type': 'License Agreement', 'text': 'Neither party \nacquires rights to the other party’s Confidential Information, and a  Receiving Party shall hold harmless the Disclosing Party and its personnel, from \nany unauthorized use or disc losure by the Receiving Party, or its suppliers, of the Disclosing Party’s Confidential Information. 5.4. Disclosures  Required by Law. The Receiving Party may release Confidential Information as required to comply with applicable \nlaw, regulation, valid court o rder, or other binding requirement of a competent governmental authority, provided that in any such case, where permitted \nby applicable law: (i) the Receiving Party will immediately notify the Disclosing Party in writing of any such requirement (a nd in any  event, prior to \ndisclosure of Confidential Information); (ii) the Receiving Party provides all reasonable assistance to the Disclosing Party in any attempt by the \nDocuSign Envelope ID: 493AACB6-DDC4-47B0-BE14-AF0D1DE9F7E8\nPage 7 of 26 \n \n \nDisclosing Party to limit or prevent the disclosure of Confidential Information; and (iii) t he Receiving Party agrees to furnish only that portion of the \nConfidential Information that is legally required to be furnished and, in consultation with the Disclosing Party, to use all reasonable efforts to ensure, to \nthe extent possible, that the inform ation is maintained in confidence by the party to whom it is furnished. 5.5. Exceptions .'}
#
# --- Processing Query: 'What is Amendment #4 to the Verisk Health License Agreement about?' ---
# Retrieved 5
#     Metadata 1: {'solution_line': 'Record Import/Clean Up', 'document_type': 'Regulatory Addendum/Exhibit', 'attorneys': ['Dynamics SVC', 'Brooke Eckstrom'], 's3_path': 's3://ml-legal-restricted/contract-docs/54155/Aetna Medicare Services Exhibit.pdf', 'dates': ['2018-11-09', '2013-01-01'], 'contract_title': 'Aetna- Reg Addend 2 to MSA 1- Medicare', 'text': 'AMEND-001-HL&S-Verisk(HealthRisk)-2010 Page 8 of 8', 'status_reason': 'Fully-Executed/Complete'}
#     Metadata 2: {'text': 'Amendment No. 02to\n\n\n                      Master Software License Agreement\n\n\n\n      This Amendment No. 02 (this “Amendment”) is entered  inteffectiveo  as\nof  August  1,  2018  (the  “Amendment  Effective  Date”)  between  1199SEIU\nNational  Benefit  Fund  for  Health  and  Human  Service   Employees   (the\n“Customer”) and Verscend Technologies, Inc., successor in  interest  to  the\nHealth Payer business unit of General Dynamics Information Technology,  Inc.\n(“Verscend”). WHEREAS, the Customer and Verscend are parties to the Master  Software\nLicense Agreement entered into as  of  December  22,  2017,  as  amended  by\nAmendment No. 01  entered  into  as  of  May  8,  2018  (collectively,  the\n“Agreement”). WHEREAS, the Customer and Verscend have agreed, subject to  the  terms\nand conditions  hereof,  to  amend  the  Agreement  as  set  forth  in  this\nAmendment. NOW, THEREFORE, for good and valuable consideration, the  receipt  and\nsufficiency of which are hereby acknowledged, the parties  hereby  agree  as\nfollows:\n\n\n   1. Amendments. (a)  Verscend  shall  provide  HealthConnect  Services  for  the\nSoftware, as set forth in the  HealthConnect  Services  Supplement  attached\nhereto as HealthConnect Services  Supplement  Exhibit  A,  and  incorporated\nherein by reference. 2. Amendment Effective Date. This Amendment shall be effective  as\nof the Amendment Effective Date. 3. Capitalized Terms; Effect of  Amendment;  Miscellaneous. Unless\notherwise defined herein, capitalized terms used herein  have  the  meanings\nset forth in the Agreement. The Agreement, as amended  hereby,  is  in  full\nforce and effect and is hereby ratified and confirmed in all respects. The\nexecution, delivery and effectiveness of this Amendment  shall  not,  except\nas expressly provided herein, (a) operate as, or  constitute,  a  waiver  of\nany right, power or remedy under the Agreement or (b) amend,  supplement  or\notherwise modify the  Agreement.', 'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/52910/Verscend (General Dynamic GDIT) MSLA STARSSol Amend2 to add Hosting service 7-30-18 (002).DOC', 'document_type': 'Amendment', 'solution_line': 'Payment Accuracy', 'dates': ['2018-07-13', '2018-10-05'], 'attorneys': ['Jerry Monahan', 'Sarah Lowdon'], 'contract_title': '1199 SEIU- Amend 2 to MSA 3 (#52376)- STARS'}
#     Metadata 3: {'status_reason': 'Fully-Executed/Complete', 's3_path': 's3://ml-legal-restricted/contract-docs/52910/1199 MSLA STARSSol Amend2 7-28-18.doc', 'text': 'Amendment No. 02to\n\n\n                      Master Software License Agreement\n\n\n\n      This Amendment No. 02 (this “Amendment”) is entered into as of  August\n1, 2018 (the “Amendment Effective Date”) between 1199SEIU  National  Benefit\nFund for Health and Human Service Employees (the  “Customer”)  and  Verscend\nTechnologies, Inc., successor in interest to the Health Payer business  unit\nof General Dynamics Information Technology, Inc. (“Verscend”). WHEREAS, the Customer and Verscend are parties to the Master  Software\nLicense Agreement entered into as  of  December  22,  2017,  as  amended  by\nAmendment No. 01  entered  into  as  of  May  8,  2018  (collectively,  the\n“Agreement”). WHEREAS, the Customer and Verscend have agreed, subject to  the  terms\nand conditions  hereof,  to  amend  the  Agreement  as  set  forth  in  this\nAmendment. NOW, THEREFORE, for good and valuable consideration, the  receipt  and\nsufficiency of which are hereby acknowledged, the parties  hereby  agree  as\nfollows:\n\n\n   1. Amendments. (a)  Verscend  shall  provide  HealthConnect  Services  for  the\nSoftware, as set forth in the  HealthConnect  Services  Supplement  attached\nhereto as HealthConnect Services  Supplement  Exhibit  A,  and  incorporated\nherein by reference. 2. Amendment Effective Date. This Amendment shall be effective  as\nof the Amendment Effective Date. 3. Capitalized Terms; Effect of  Amendment;  Miscellaneous. Unless\notherwise defined herein, capitalized terms used herein  have  the  meanings\nset forth in the Agreement. The Agreement, as amended  hereby,  is  in  full\nforce and effect and is hereby ratified and confirmed in all respects. The\nexecution, delivery and effectiveness of this Amendment  shall  not,  except\nas expressly provided herein, (a) operate as, or  constitute,  a  waiver  of\nany right, power or remedy under the Agreement or (b) amend,  supplement  or\notherwise modify the  Agreement.', 'contract_title': '1199 SEIU- Amend 2 to MSA 3 (#52376)- STARS', 'dates': ['2018-07-13', '2018-10-05'], 'attorneys': ['Jerry Monahan', 'Sarah Lowdon'], 'solution_line': 'Payment Accuracy', 'document_type': 'Amendment'}
#     Metadata 4: {'text': 'Amendment No. 02 to\nMaster Software License Agreement\n\nThis Amendment No. 02 (this “Amendment”) is effective as of the last dated signature below (the “Amendment Effective\nDate”) between 1199SEIU National Benefit Fund for Health and Human Service Employees (the “Customer”) and Verscend\n\nTechnologies, Inc., successor in interest to the Health Payer business unit of General Dynamics Information Technology, Inc.\n(“Verscend”). WHEREAS, the Customer and Verscend are parties to the Master Software License Agreement entered into as of December\n22, 2017, as amended by Amendment No. 01 entered into as of May 8, 2018 (collectively, the “Agreement”). WHEREAS, the Customer and Verscend have agreed, subject to the terms and conditions hereof, to amend the Agreement as\nset forth in this Amendment. NOW, THEREFORE, for good and valuable consideration, the receipt and sufficiency of which are hereby acknowledged,\nthe parties hereby agree as follows:\n\n1. Amendments. (a) Verscend shall provide HealthConnect Services for the Software, as set forth in the HealthConnect Services\nSupplement attached hereto as HealthConnect Services Supplement Exhibit A, and incorporated herein by reference. 2. Amendment Effective Date. This Amendment shall be effective as of the Amendment Effective Date. 3. Capitalized Terms: Effect of Amendment; Miscellaneous. Unless otherwise defined herein, capitalized terms used herein\nhave the meanings set forth in the Agreement. The Agreement, as amended hereby, is in full force and effect and is hereby ratified and\nconfirmed in all respects. The execution, delivery and effectiveness of this Amendment shall not, except as expressly provided herein,\n(a) operate as, or constitute, a waiver of any right, power or remedy under the Agreement or (b) amend, supplement or otherwise modify\nthe Agreement.', 'document_type': 'Amendment', 'solution_line': 'Payment Accuracy', 'contract_title': '1199 SEIU- Amend 2 to MSA 3 (#52376)- STARS', 'status_reason': 'Fully-Executed/Complete', 'attorneys': ['Jerry Monahan', 'Sarah Lowdon'], 's3_path': 's3://ml-legal-restricted/contract-docs/52910/Verscend 1199 Amend2 to MLSA sgn by 1199 10-1-18.pdf', 'dates': ['2018-07-13', '2018-10-05']}
#     Metadata 5: {'s3_path': 's3://ml-legal-restricted/contract-docs/52910/1199 MSLA STARSSol Amend2 09-05-18 SEL.doc', 'text': 'Amendment No. 02to\n\n\n                      Master Software License Agreement\n\n\n\n      This Amendment No. 02 (this “Amendment”) is effective as of August  1,\n2018the last dated signature below (the “Amendment Effective Date”)  between\n1199SEIU National Benefit Fund for Health and Human Service  Employees  (the\n“Customer”) and Verscend Technologies, Inc., successor in  interest  to  the\nHealth Payer business unit of General Dynamics Information Technology,  Inc.\n(“Verscend”). WHEREAS, the Customer and Verscend are parties to the Master  Software\nLicense Agreement entered into as  of  December  22,  2017,  as  amended  by\nAmendment No. 01  entered  into  as  of  May  8,  2018  (collectively,  the\n“Agreement”). WHEREAS, the Customer and Verscend have agreed, subject to  the  terms\nand conditions  hereof,  to  amend  the  Agreement  as  set  forth  in  this\nAmendment. NOW, THEREFORE, for good and valuable consideration, the  receipt  and\nsufficiency of which are hereby acknowledged, the parties  hereby  agree  as\nfollows:\n\n\n   1. Amendments. (a)  Verscend  shall  provide  HealthConnect  Services  for  the\nSoftware, as set forth in the  HealthConnect  Services  Supplement  attached\nhereto as HealthConnect Services  Supplement  Exhibit  A,  and  incorporated\nherein by reference. 2. Amendment Effective Date. This Amendment shall be effective  as\nof the Amendment Effective Date. 3. Capitalized Terms; Effect of  Amendment;  Miscellaneous. Unless\notherwise defined herein, capitalized terms used herein  have  the  meanings\nset forth in the Agreement. The Agreement, as amended  hereby,  is  in  full\nforce and effect and is hereby ratified and confirmed in all respects. The\nexecution, delivery and effectiveness of this Amendment  shall  not,  except\nas expressly provided herein, (a) operate as, or  constitute,  a  waiver  of\nany right, power or remedy under the Agreement or (b) amend,  supplement  or\notherwise modify the  Agreement.', 'attorneys': ['Jerry Monahan', 'Sarah Lowdon'], 'solution_line': 'Payment Accuracy', 'status_reason': 'Fully-Executed/Complete', 'contract_title': '1199 SEIU- Amend 2 to MSA 3 (#52376)- STARS', 'dates': ['2018-07-13', '2018-10-05'], 'document_type': 'Amendment'}
#
# --- Processing Query: 'What is the purpose of Amendment #4 as stated in the document?' ---
# Retrieved 5
#     Metadata 1: {'document_type': 'Amendment', 's3_path': 's3://ml-legal-restricted/contract-docs/76086/CVS - Cotiviti - AMD 4 - MS - 12262024 - Dynamics_76086.pdf', 'dates': ['2024-11-13', '2025-01-01'], 'contract_title': 'Amd 4 to Sched 11 Renewal CCV DM/COB 2025', 'text': 'As \nsuch, any definitions, obligations,  or requirements in the Agreement  shall apply to  this Amendment  4, as though \nfully set forth herein. In the event of conflict between the  Agreement  and this Amendment  4, this Amendment  4 \nshall govern. 6 \n Each pa rty represents and warrants to the other that this Amendment  4 has been duly  authorized, \nexecuted and delivered by it and constitutes a valid and enforceable obligation  of such party in  accordance with \nits terms. This Amendment  4 may be executed in two or more counterparts, each of which shall be deemed to be \nan original as against any party whose signature appears thereon, but all of  which together shall constitute one \nand the same instrument. IN WITNESS WHEREOF, the parties have executed this Amendment  4 by their respective authorized \nrepresentatives as of the first date specified above. COTIVITI, INC .', 'status_reason': 'Fully-Executed/Complete', 'attorneys': ['Nishan Khoshafian', 'Melissa Syracuse'], 'solution_line': 'Payment Accuracy'}
#     Metadata 2: {'text': 'IN WITNESS WHEREOF, the parties hereto have caused this Amendment to be executed by their respective duly authorized officers or agents as of the date first above written.', 'document_type': 'Amendment', 'dates': ['2021-08-04', '2022-01-01'], 'contract_title': 'Amend 1 to Sch 19 (Quality Record Repository AMD Renewal)', 'status_reason': 'Fully-Executed/Complete', 'solution_line': 'Quality Improvement', 'attorneys': ['Nishan Khoshafian', 'Saloni Choudhry'], 's3_path': 's3://ml-legal-restricted/contract-docs/62561/Aetna-Cotiviti Inc - Amendment 1 to Schedule 19 - Client Release 4.0(12.08.21).docx'}
#     Metadata 3: {'dates': ['2020-04-26', '2020-07-10'], 'solution_line': 'Risk Adjustment', 'attorneys': ['Tony Potts', 'Sarah Lowdon'], 'text': 'IN WITNESS WHEREOF, the parties hereto have caused this Amendment to be executed by their respective duly authorized officers or agents as of the date first above written.', 's3_path': 's3://ml-legal-restricted/contract-docs/59240/Aetna-Cotiviti Inc (fka Verisk Health Inc fka Health Risk Partners)- Amendment No. 5 to Schedule No. 011 SEL.docx', 'status_reason': 'Fully-Executed/Complete', 'document_type': 'Amendment', 'contract_title': 'Aetna - Cotiviti - Sentinel AMD5 to SCH11'}
#     Metadata 4: {'text': '[Signature Page to Follow]\n\n\n\n\n\n\nIN WITNESS WHEREOF, the parties hereto have caused this Amendment to be executed by their respective duly authorized officers or agents as of the date first above written.', 'status_reason': 'Fully-Executed/Complete', 'dates': ['2021-11-18', '2022-01-01'], 'document_type': 'Amendment', 'contract_title': 'Aetna-Postpay Medicaid Renewal AMD #5 to SCD 12', 'solution_line': 'Payment Accuracy', 'attorneys': ['Nishan Khoshafian', 'ihtech Simko'], 's3_path': 's3://ml-legal-restricted/contract-docs/63349/Aetna-Cotiviti-Amendment No. 5 to Schedule 12 (11.17.21 INTERNAL REVIEW DRAFT).docx'}
#     Metadata 5: {'contract_title': 'Aetna Cap Amendment CV', 'dates': ['2020-02-10', '2020-02-10'], 'document_type': 'Amendment', 's3_path': 's3://ml-legal-restricted/contract-docs/58738/Aetna- Cotiviti Inc (iht)-Health Care Technology SA- Amendment No. 024 CW2302096 - unsigned.docx', 'status_reason': 'Fully-Executed/Complete', 'solution_line': 'Payment Accuracy', 'attorneys': ['Lori Walsh', 'Jeffrey Koslowski'], 'text': 'IN WITNESS WHEREOF, the Parties have hereto by their duly authorized representatives executed this Amendment.\u202c\u202c'}
